# %% [markdown]
# <a href="https://colab.research.google.com/github/mrgoudsaab/Ranjithgoud/blob/main/box_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Create a sample dataset with some outliers
np.random.seed (10)
data = pd.DataFrame({
'value': np.concatenate ([np.random.normal(0, 1, 100), np.random.normal(10, 1, 10)])
})
# Calculate the IQR for box plot-based outlier detection
Q1 = data['value'].quantile(0.25)
Q3= data['value'].quantile(0.75)
IQR = Q3 - Q1
# Define outlier thresholds
lower_bound = Q1 + 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers = data[(data['value'] < lower_bound) | (data['value'] > upper_bound)]
print(outliers)
plt.figure(figsize=(12,6))

plt.subplot(1,2,1)
sns.boxplot(x=data['value'])
plt.title('Box Plot of Data')
plt.xlabel('Value')
plt.ylabel('Frequency')

plt.subplot(1,2,2)
# Out:
#          value
# 0     1.331587
# 1     0.715279
# 2    -1.545400
# 3    -0.008384
# 4     0.621336
# ..         ...
# 105   9.599862
# 106   9.704016
# 107  10.848209
# 108  10.706830
# 109   9.212731
#
# [104 rows x 1 columns]
# <Axes: >
