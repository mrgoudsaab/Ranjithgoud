# %% [markdown]
# <a href="https://colab.research.google.com/github/mrgoudsaab/Ranjithgoud/blob/main/scatter_plots.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import statistics
import numpy as np
stock_prices = [100, 102, 98, 105, 101, 97, 99, 103, 100, 98]
variance = statistics.variance(stock_prices)
print(f"Variance of stock prices: {variance}")
numpy_variance = np.var(stock_prices, ddof=1) # ddof=1 for sample variance
print (f"Variance of stock prices (using NumPy): {numpy_variance}")
# Out:
# Variance of stock prices: 6.233333333333333
# Variance of stock prices (using NumPy): 6.2333333333333325

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    'Temperature': [22, 25, 28, 18, 21, 19, 24, 26, 23, 27, 28, 30, 31, 32, 34, 35, 23, 15, 12, 14, 24, 23, 20, 19, 18, 23],
    'Humidity': [65, 60, 72, 78, 70, 75, 80, 68, 69, 73, 65, 60, 72, 78, 70, 75, 80, 68, 69, 73, 65, 60, 72, 78, 70, 75],
    'Wind Speed': [15, 10, 20, 25, 12, 14, 18, 22, 11, 19, 15, 10, 20, 25, 12, 14, 18, 22, 11, 19, 15, 10, 20, 25, 12, 14],
    'Pressure': [1015, 1012, 1017, 1014, 1013, 1016, 1011, 1018, 1015, 1013, 1015, 1012, 1017, 1014, 1013, 1016, 1011, 1018, 1015, 1013, 1015, 1012, 1017, 1014, 1013, 1016]
}

df = pd.DataFrame(data)

plt.figure(figsize=(8, 6))
plt.scatter(df['Temperature'], df['Humidity'], color='blue', label='Temp vs Humidity')
plt.title('Temperature vs Humidity', fontsize=14)
plt.xlabel('Temperature')
plt.ylabel('Humidity')
plt.legend()
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

data = {
    'Temperature': [22, 25, 28, 18, 21, 19, 24, 26, 23, 27, 28, 30, 31, 32, 34, 35, 23, 15, 12, 14, 24, 23, 20, 19, 18, 23, 25, 29, 33, 28, 22, 27, 21, 30, 26, 24, 19, 20, 22, 25],
    'Humidity': [65, 60, 72, 78, 70, 75, 80, 68, 69, 73, 65, 60, 72, 78, 70, 75, 80, 68, 69, 73, 65, 60, 72, 78, 70, 75, 65, 63, 77, 71, 74, 69, 67, 79, 76, 70, 65, 68, 72, 74],
    'Wind Speed': [15, 10, 20, 25, 12, 14, 18, 22, 11, 19, 15, 10, 20, 25, 12, 14, 18, 22, 11, 19, 15, 10, 20, 25, 12, 14, 17, 21, 16, 19, 13, 15, 18, 22, 11, 20, 14, 19, 16, 15],
    'Pressure': [1015, 1012, 1017, 1014, 1013, 1016, 1011, 1018, 1015, 1013, 1015, 1012, 1017, 1014, 1013, 1016, 1011, 1018, 1015, 1013, 1015, 1012, 1017, 1014, 1013, 1016, 1010, 1019, 1012, 1015, 1014, 1016, 1013, 1017, 1011, 1014, 1018, 1015, 1012, 1016]
}

df = pd.DataFrame(data)


# Scatter plot
plt.figure(figsize=(8, 6))
plt.scatter(df['Temperature'], df['Humidity'], color='blue', label='Temp vs Humidity')
plt.title('Temperature vs Humidity', fontsize=14)
plt.xlabel('Temperature')
plt.ylabel('Humidity')
plt.legend()
plt.show()



sns.pairplot(df, diag_kind="kde", plot_kws={"alpha": 0.7})
plt.show()
